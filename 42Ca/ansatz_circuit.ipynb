# %% [markdown]
# ## 42Caの状態作成回路
#
# valenceを40Caとして、$M=0$となる核子pairに1つのqubitが割り振られる。
# モデル空間はpf-shellである。
# したがって、$p_{1/2}$の$|j_{z}|=1/2$、$p_{3/2}$の$|j_{z}|=1/2,3/2$、$f_{5/2}$の$|j_{z}|=1/2,3/2,5/2$、$f_{7/2}$の$|j_{z}|=1/2,3/2,5/2,7/2$の10パターン存在する。
#
# 以下、$|0000000001\rangle,\cdots,|1000000000\rangle$の重ね合わせ状態を作る回路の作成を行う。

# %%
import sys
#! pip install pylatexenc
import numpy as np
from scipy import linalg
import sympy
import itertools
from itertools import combinations
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram
from qiskit_aer import Aer
from qiskit.quantum_info import Statevector, SparsePauliOp
from qiskit.synthesis import SuzukiTrotter
import seaborn as sns
from tqdm import tqdm
from qiskit_aer.primitives import SamplerV2
from qiskit.primitives import StatevectorSampler

# %%
def G1(theta):
    theta = theta * 2
    circ = QuantumCircuit(2)
    circ.x(0)
    circ.ry(theta, 1)
    circ.cx(1, 0)
    circ.name = f'G1({theta:.2f})'
    return circ.to_gate()

def G(theta):
    theta = theta * 2
    circ = QuantumCircuit(2)
    circ.cry(theta, 0, 1)
    circ.cx(1, 0)
    circ.name = f'G({theta:.2f})'
    return circ.to_gate()

params = [np.pi/4, np.pi/4,np.pi/4, np.pi/4, np.pi/4, np.pi/4, np.pi/4, np.pi/4, np.pi/4, np.pi/4]
qc = QuantumCircuit(10)
qc.append(G1(params[0]), [0, 1])
qc.append(G(params[1]), [1, 2])
qc.append(G(params[2]), [2, 3])
qc.append(G(params[3]), [3, 4])
qc.append(G(params[4]), [4, 5])
qc.append(G(params[5]), [5, 6])
qc.append(G(params[6]), [6, 7])
qc.append(G(params[7]), [7, 8])
qc.append(G(params[8]), [8, 9])
qc.draw('mpl')

# %%
state_vector = Statevector.from_instruction(qc)
state_vector
state_vector.draw('latex')
# Out:
# $$\frac{\sqrt{2}}{2} |0000000001\rangle+\frac{1}{2} |0000000010\rangle+\frac{\sqrt{2}}{4} |0000000100\rangle+\frac{1}{4} |0000001000\rangle+0.1767766953 |0000010000\rangle+\frac{1}{8} |0000100000\rangle+0.0883883476 |0001000000\rangle+\frac{1}{16} |0010000000\rangle+0.0441941738 |0100000000\rangle+0.0441941738 |1000000000\rangle$$
